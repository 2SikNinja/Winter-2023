# %%
# import the libraries
import numpy as np
import math

# %% [markdown]
# ## Implement its gradient vector, which is an exercise presented on Slide 39 of Topic 3.1
#
# ![gradient1.PNG](data:image/png;base64,...)

# %%
## a function returns the Gradient vector at the input vector x_i
## note: the expression of each element in the Gradient vector is hard-coded based on the formula presented above, which is also given on Slide 40 of Topic 3.1
def getGradientVector(x_i):
  g = np.zeros((4,1))
  g[0] = 2 * (x_i[0] + 10*x_i[1]) + 40 * (x_i[0] - x_i[3]) * (x_i[0] - x_i[3]) * (x_i[0] - x_i[3]) 
  g[1] = 20 * (x_i[0] + 10*x_i[1]) + 4 * (x_i[1] - 2*x_i[2]) * (x_i[1] - 2*x_i[2]) * (x_i[1] - 2*x_i[2])
  g[2] = 10 * (x_i[2] - x_i[3]) - 8 * (x_i[1] - 2*x_i[2]) * (x_i[1] - 2*x_i[2]) * (x_i[1] - 2*x_i[2])
  g[3] = -10 * (x_i[2] - x_i[3]) - 40 * (x_i[0] - x_i[3]) * (x_i[0] - x_i[3]) * (x_i[0] - x_i[3])
  return g

# a simple function returns the norm of an input vector
def getNorm(v):
  return math.sqrt(v[0]*v[0]+v[1]*v[1]+v[2]*v[2]+v[3]*v[3])

# %% [markdown]
# ## Perform the Gradient Descent Method for minimizing the nonlinear function
#
# ![gradient2.PNG](data:image/png;base64,...)

# %%
## set an initial guess
x_0 = np.array([[3], [-1], [0], [1]])
print(f"--The initial guess x0: ")
print(x_0)

## set a threshold value for getting a good solution
thresh = 0.01

## set step length 
alpha = 0.001

x_i = x_0
count = 0
while True:
  print('****************************************************')
  print(f'--At iteration: {count}')
  
  ## compute the gradient vector at x_i
  g = getGradientVector(x_i)
  print(f"--The gradient vector g(x_{count}): ")
  print(g)

  ## compute the norm of the gradient vector at x_i
  normOfGradient = getNorm(g)
  print(f"--The norm of the gradient vector |g(x_{count})|: {normOfGradient}")

  ## check if converged; if true, then stop; continue otherwise
  if normOfGradient <= thresh:
    break


  ## get h=-g
  h_i = -1*g
  print(f"--The h vector h_{count}: ")
  print(h_i)

  ## get the new solution point
  x_i_plus1 = x_i + alpha * h_i
  print(f"--The solution vector x_{count+1}: ")
  print(x_i_plus1)

  x_i = x_i_plus1
  count = count + 1
  print()
# Out:
# Streaming output truncated to the last 5000 lines.
#  [ 0.00415469]
#  [ 0.0044225 ]]
# --The norm of the gradient vector |g(x_7691)|: 0.010573088328303056
# --The h vector h_7691:
# [[-0.00861635]
#  [ 0.00085366]
#  [-0.00415469]
#  [-0.0044225 ]]
# --The solution vector x_7692:
# [[ 0.11715465]
#  [-0.0116786 ]
#  [ 0.05774517]
#  [ 0.05897504]]
#
# ****************************************************
# --At iteration: 7692
# --The gradient vector g(x_7692):
# [[ 0.00861449]
#  [-0.00085348]
#  [ 0.00415381]
#  [ 0.00442153]]
# --The norm of the gradient vector |g(x_7692)|: 0.010570802377823095
# --The h vector h_7692:
# [[-0.00861449]
#  [ 0.00085348]
#  [-0.00415381]
#  [-0.00442153]]
# --The solution vector x_7693:
# [[ 0.11714603]
#  [-0.01167775]
#  [ 0.05774101]
#  [ 0.05897062]]
#
# ****************************************************
# --At iteration: 7693
# --The gradient vector g(x_7693):
# [[ 0.00861262]
#  [-0.00085329]
#  [ 0.00415293]
#  [ 0.00442055]]
# --The norm of the gradient vector |g(x_7693)|: 0.010568517241105323
# --The h vector h_7693:
# [[-0.00861262]
#  [ 0.00085329]
#  [-0.00415293]
#  [-0.00442055]]
# --The solution vector x_7694:
# [[ 0.11713742]
#  [-0.01167689]
#  [ 0.05773686]
#  [ 0.0589662 ]]
#
# ****************************************************
# --At iteration: 7694
# --The gradient vector g(x_7694):
# [[ 0.00861076]
#  [-0.00085311]
#  [ 0.00415205]
#  [ 0.00441958]]
# --The norm of the gradient vector |g(x_7694)|: 0.010566232917747753
# --The h vector h_7694:
# [[-0.00861076]
#  [ 0.00085311]
#  [-0.00415205]
#  [-0.00441958]]
# --The solution vector x_7695:
# [[ 0.11712881]
#  [-0.01167604]
#  [ 0.05773271]
#  [ 0.05896178]]
#
# ****************************************************
# --At iteration: 7695
# --The gradient vector g(x_7695):
# [[ 0.0086089 ]
#  [-0.00085293]
#  [ 0.00415118]
#  [ 0.00441861]]
# --The norm of the gradient vector |g(x_7695)|: 0.010563949407348647
# --The h vector h_7695:
# [[-0.0086089 ]
#  [ 0.00085293]
#  [-0.00415118]
#  [-0.00441861]]
# --The solution vector x_7696:
# [[ 0.1171202 ]
#  [-0.01167519]
#  [ 0.05772856]
#  [ 0.05895736]]
#
# ****************************************************
# --At iteration: 7696
# --The gradient vector g(x_7696):
# [[ 0.00860704]
#  [-0.00085274]
#  [ 0.0041503 ]
#  [ 0.00441763]]
# --The norm of the gradient vector |g(x_7696)|: 0.010561666709506522
# --The h vector h_7696:
# [[-0.00860704]
#  [ 0.00085274]
#  [-0.0041503 ]
#  [-0.00441763]]
# --The solution vector x_7697:
# [[ 0.11711159]
#  [-0.01167434]
#  [ 0.05772441]
#  [ 0.05895294]]
#
# ****************************************************
# --At iteration: 7697
# --The gradient vector g(x_7697):
# [[ 0.00860518]
#  [-0.00085256]
#  [ 0.00414942]
#  [ 0.00441666]]
# --The norm of the gradient vector |g(x_7697)|: 0.010559384823820153
# --The h vector h_7697:
# [[-0.00860518]
#  [ 0.00085256]
#  [-0.00414942]
#  [-0.00441666]]
# --The solution vector x_7698:
# [[ 0.11710299]
#  [-0.01167348]
#  [ 0.05772026]
#  [ 0.05894853]]
#
# ****************************************************
# --At iteration: 7698
# --The gradient vector g(x_7698):
# [[ 0.00860332]
#  [-0.00085238]
#  [ 0.00414855]
#  [ 0.00441569]]
# --The norm of the gradient vector |g(x_7698)|: 0.010557103749888557
# --The h vector h_7698:
# [[-0.00860332]
#  [ 0.00085238]
#  [-0.00414855]
#  [-0.00441569]]
# --The solution vector x_7699:
# [[ 0.11709438]
#  [-0.01167263]
#  [ 0.05771611]
#  [ 0.05894411]]
#
# ****************************************************
# --At iteration: 7699
# --The gradient vector g(x_7699):
# [[ 0.00860146]
#  [-0.00085219]
#  [ 0.00414767]
#  [ 0.00441472]]
# --The norm of the gradient vector |g(x_7699)|: 0.010554823487311016
# --The h vector h_7699:
# [[-0.00860146]
#  [ 0.00085219]
#  [-0.00414767]
#  [-0.00441472]]
# --The solution vector x_7700:
# [[ 0.11708578]
#  [-0.01167178]
#  [ 0.05771196]
#  [ 0.0589397 ]]
#
# ****************************************************
# --At iteration: 7700
# --The gradient vector g(x_7700):
# [[ 0.00859961]
#  [-0.00085201]
#  [ 0.00414679]
#  [ 0.00441374]]
# --The norm of the gradient vector |g(x_7700)|: 0.010552544035687061
# --The h vector h_7700:
# [[-0.00859961]
#  [ 0.00085201]
#  [-0.00414679]
#  [-0.00441374]]
# --The solution vector x_7701:
# [[ 0.11707718]
#  [-0.01167093]
#  [ 0.05770782]
#  [ 0.05893528]]
#
# ****************************************************
# --At iteration: 7701
# --The gradient vector g(x_7701):
# [[ 0.00859775]
#  [-0.00085183]
#  [ 0.00414592]
#  [ 0.00441277]]
# --The norm of the gradient vector |g(x_7701)|: 0.010550265394616464
# --The h vector h_7701:
# [[-0.00859775]
#  [ 0.00085183]
#  [-0.00414592]
#  [-0.00441277]]
# --The solution vector x_7702:
# [[ 0.11706859]
#  [-0.01167007]
#  [ 0.05770367]
#  [ 0.05893087]]
#
# ****************************************************
# --At iteration: 7702
# --The gradient vector g(x_7702):
# [[ 0.00859589]
#  [-0.00085165]
#  [ 0.00414504]
#  [ 0.0044118 ]]
# --The norm of the gradient vector |g(x_7702)|: 0.010547987563699268
# --The h vector h_7702:
# [[-0.00859589]
#  [ 0.00085165]
#  [-0.00414504]
#  [-0.0044118 ]]
# --The solution vector x_7703:
# [[ 0.11705999]
#  [-0.01166922]
#  [ 0.05769952]
#  [ 0.05892646]]
#
# ****************************************************
# --At iteration: 7703
# --The gradient vector g(x_7703):
# [[ 0.00859404]
#  [-0.00085146]
#  [ 0.00414417]
#  [ 0.00441083]]
# --The norm of the gradient vector |g(x_7703)|: 0.010545710542535754
# --The h vector h_7703:
# [[-0.00859404]
#  [ 0.00085146]
#  [-0.00414417]
#  [-0.00441083]]
# --The solution vector x_7704:
# [[ 0.1170514 ]
#  [-0.01166837]
#  [ 0.05769538]
#  [ 0.05892205]]
#
# ****************************************************
# --At iteration: 7704
# --The gradient vector g(x_7704):
# [[ 0.00859218]
#  [-0.00085128]
#  [ 0.00414329]
#  [ 0.00440986]]
# --The norm of the gradient vector |g(x_7704)|: 0.010543434330726461
# --The h vector h_7704:
# [[-0.00859218]
#  [ 0.00085128]
#  [-0.00414329]
#  [-0.00440986]]
# --The solution vector x_7705:
# [[ 0.1170428 ]
#  [-0.01166752]
#  [ 0.05769124]
#  [ 0.05891764]]
#
# ****************************************************
# --At iteration: 7705
# --The gradient vector g(x_7705):
# [[ 0.00859033]
#  [-0.0008511 ]
#  [ 0.00414242]
#  [ 0.00440889]]
# --The norm of the gradient vector |g(x_7705)|: 0.010541158927872182
# --The h vector h_7705:
# [[-0.00859033]
#  [ 0.0008511 ]
#  [-0.00414242]
#  [-0.00440889]]
# --The solution vector x_7706:
# [[ 0.11703421]
#  [-0.01166667]
#  [ 0.05768709]
#  [ 0.05891323]]
#
# ****************************************************
# --At iteration: 7706
# --The gradient vector g(x_7706):
# [[ 0.00858847]
#  [-0.00085092]
#  [ 0.00414154]
#  [ 0.00440792]]
# --The norm of the gradient vector |g(x_7706)|: 0.010538884333573946
# --The h vector h_7706:
# [[-0.00858847]
#  [ 0.00085092]
#  [-0.00414154]
#  [-0.00440792]]
# --The solution vector x_7707:
# [[ 0.11702562]
#  [-0.01166582]
#  [ 0.05768295]
#  [ 0.05890882]]
#
# ****************************************************
# --At iteration: 7707
# --The gradient vector g(x_7707):
# [[ 0.00858662]
#  [-0.00085073]
#  [ 0.00414067]
#  [ 0.00440695]]
# --The norm of the gradient vector |g(x_7707)|: 0.010536610547433052
# --The h vector h_7707:
# [[-0.00858662]
#  [ 0.00085073]
#  [-0.00414067]
#  [-0.00440695]]
# --The solution vector x_7708:
# [[ 0.11701704]
#  [-0.01166497]
#  [ 0.05767881]
#  [ 0.05890441]]
#
# ****************************************************
# --At iteration: 7708
# --The gradient vector g(x_7708):
# [[ 0.00858477]
#  [-0.00085055]
#  [ 0.0041398 ]
#  [ 0.00440598]]
# --The norm of the gradient vector |g(x_7708)|: 0.010534337569051052
# --The h vector h_7708:
# [[-0.00858477]
#  [ 0.00085055]
#  [-0.0041398 ]
#  [-0.00440598]]
# --The solution vector x_7709:
# [[ 0.11700845]
#  [-0.01166412]
#  [ 0.05767467]
#  [ 0.05890001]]
#
# ****************************************************
# --At iteration: 7709
# --The gradient vector g(x_7709):
# [[ 0.00858292]
#  [-0.00085037]
#  [ 0.00413892]
#  [ 0.00440501]]
# --The norm of the gradient vector |g(x_7709)|: 0.010532065398029719
# --The h vector h_7709:
# [[-0.00858292]
#  [ 0.00085037]
#  [-0.00413892]
#  [-0.00440501]]
# --The solution vector x_7710:
# [[ 0.11699987]
#  [-0.01166327]
#  [ 0.05767053]
#  [ 0.0588956 ]]
#
# ****************************************************
# --At iteration: 7710
# --The gradient vector g(x_7710):
# [[ 0.00858106]
#  [-0.00085019]
#  [ 0.00413805]
#  [ 0.00440405]]
# --The norm of the gradient vector |g(x_7710)|: 0.010529794033971114
# --The h vector h_7710:
# [[-0.00858106]
#  [ 0.00085019]
#  [-0.00413805]
#  [-0.00440405]]
# --The solution vector x_7711:
# [[ 0.11699129]
#  [-0.01166242]
#  [ 0.0576664 ]
#  [ 0.0588912 ]]
#
# ****************************************************
# --At iteration: 7711
# --The gradient vector g(x_7711):
# [[ 0.00857921]
#  [-0.00085   ]
#  [ 0.00413718]
#  [ 0.00440308]]
# --The norm of the gradient vector |g(x_7711)|: 0.01052752347647752
# --The h vector h_7711:
# [[-0.00857921]
#  [ 0.00085   ]
#  [-0.00413718]
#  [-0.00440308]]
# --The solution vector x_7712:
# [[ 0.11698271]
#  [-0.01166157]
#  [ 0.05766226]
#  [ 0.0588868 ]]
#
# ****************************************************
# --At iteration: 7712
# --The gradient vector g(x_7712):
# [[ 0.00857736]
#  [-0.00084982]
#  [ 0.0041363 ]
#  [ 0.00440211]]
# --The norm of the gradient vector |g(x_7712)|: 0.010525253725151488
# --The h vector h_7712:
# [[-0.00857736]
#  [ 0.00084982]
#  [-0.0041363 ]
#  [-0.00440211]]
# --The solution vector x_7713:
# [[ 0.11697413]
#  [-0.01166072]
#  [ 0.05765812]
#  [ 0.05888239]]
#
# ****************************************************
# --At iteration: 7713
# --The gradient vector g(x_7713):
# [[ 0.00857552]
#  [-0.00084964]
#  [ 0.00413543]
#  [ 0.00440114]]
# --The norm of the gradient vector |g(x_7713)|: 0.010522984779595812
# --The h vector h_7713:
# [[-0.00857552]
#  [ 0.00084964]
#  [-0.00413543]
#  [-0.00440114]]
# --The solution vector x_7714:
# [[ 0.11696556]
#  [-0.01165987]
#  [ 0.05765399]
#  [ 0.05887799]]
#
# ****************************************************
# --At iteration: 7714
# --The gradient vector g(x_7714):
# [[ 0.00857367]
#  [-0.00084946]
#  [ 0.00413456]
#  [ 0.00440018]]
# --The norm of the gradient vector |g(x_7714)|: 0.010520716639413537
# --The h vector h_7714:
# [[-0.00857367]
#  [ 0.00084946]
#  [-0.00413456]
#  [-0.00440018]]
# --The solution vector x_7715:
# [[ 0.11695698]
#  [-0.01165902]
#  [ 0.05764985]
#  [ 0.05887359]]
#
# ****************************************************
# --At iteration: 7715
# --The gradient vector g(x_7715):
# [[ 0.00857182]
#  [-0.00084928]
#  [ 0.00413369]
#  [ 0.00439921]]
# --The norm of the gradient vector |g(x_7715)|: 0.01051844930420795
# --The h vector h_7715:
# [[-0.00857182]
#  [ 0.00084928]
#  [-0.00413369]
#  [-0.00439921]]
# --The solution vector x_7716:
# [[ 0.11694841]
#  [-0.01165817]
#  [ 0.05764572]
#  [ 0.05886919]]
#
# ****************************************************
# --At iteration: 7716
# --The gradient vector g(x_7716):
# [[ 0.00856997]
#  [-0.00084909]
#  [ 0.00413282]
#  [ 0.00439824]]
# --The norm of the gradient vector |g(x_7716)|: 0.010516182773582608
# --The h vector h_7716:
# [[-0.00856997]
#  [ 0.00084909]
#  [-0.00413282]
#  [-0.00439824]]
# --The solution vector x_7717:
# [[ 0.11693984]
#  [-0.01165732]
#  [ 0.05764159]
#  [ 0.0588648 ]]
#
# ****************************************************
# --At iteration: 7717
# --The gradient vector g(x_7717):
# [[ 0.00856812]
#  [-0.00084891]
#  [ 0.00413195]
#  [ 0.00439728]]
# --The norm of the gradient vector |g(x_7717)|: 0.010513917047141297
# --The h vector h_7717:
# [[-0.00856812]
#  [ 0.00084891]
#  [-0.00413195]
#  [-0.00439728]]
# --The solution vector x_7718:
# [[ 0.11693127]
#  [-0.01165647]
#  [ 0.05763745]
#  [ 0.0588604 ]]
#
# ****************************************************
# --At iteration: 7718
# --The gradient vector g(x_7718):
# [[ 0.00856628]
#  [-0.00084873]
#  [ 0.00413108]
#  [ 0.00439631]]
# --The norm of the gradient vector |g(x_7718)|: 0.010511652124488057
# --The h vector h_7718:
# [[-0.00856628]
#  [ 0.00084873]
#  [-0.00413108]
#  [-0.00439631]]
# --The solution vector x_7719:
# [[ 0.11692271]
#  [-0.01165562]
#  [ 0.05763332]
#  [ 0.058856  ]]
#
# ****************************************************
# --At iteration: 7719
# --The gradient vector g(x_7719):
# [[ 0.00856443]
#  [-0.00084855]
#  [ 0.00413021]
#  [ 0.00439535]]
# --The norm of the gradient vector |g(x_7719)|: 0.010509388005227185
# --The h vector h_7719:
# [[-0.00856443]
#  [ 0.00084855]
#  [-0.00413021]
#  [-0.00439535]]
# --The solution vector x_7720:
# [[ 0.11691414]
#  [-0.01165477]
#  [ 0.05762919]
#  [ 0.05885161]]
#
# ****************************************************
# --At iteration: 7720
# --The gradient vector g(x_7720):
# [[ 0.00856259]
#  [-0.00084837]
#  [ 0.00412934]
#  [ 0.00439438]]
# --The norm of the gradient vector |g(x_7720)|: 0.010507124688963209
# --The h vector h_7720:
# [[-0.00856259]
#  [ 0.00084837]
#  [-0.00412934]
#  [-0.00439438]]
# --The solution vector x_7721:
# [[ 0.11690558]
#  [-0.01165392]
#  [ 0.05762506]
#  [ 0.05884721]]
#
# ****************************************************
# --At iteration: 7721
# --The gradient vector g(x_7721):
# [[ 0.00856074]
#  [-0.00084818]
#  [ 0.00412847]
#  [ 0.00439342]]
# --The norm of the gradient vector |g(x_7721)|: 0.010504862175300934
# --The h vector h_7721:
# [[-0.00856074]
#  [ 0.00084818]
#  [-0.00412847]
#  [-0.00439342]]
# --The solution vector x_7722:
# [[ 0.11689702]
#  [-0.01165308]
#  [ 0.05762093]
#  [ 0.05884282]]
#
# ****************************************************
# --At iteration: 7722
# --The gradient vector g(x_7722):
# [[ 0.0085589 ]
#  [-0.000848  ]
#  [ 0.0041276 ]
#  [ 0.00439246]]
# --The norm of the gradient vector |g(x_7722)|: 0.010502600463845383
# --The h vector h_7722:
# [[-0.0085589 ]
#  [ 0.000848  ]
#  [-0.0041276 ]
#  [-0.00439246]]
# --The solution vector x_7723:
# [[ 0.11688846]
#  [-0.01165223]
#  [ 0.05761681]
#  [ 0.05883843]]
#
# ****************************************************
# --At iteration: 7723
# --The gradient vector g(x_7723):
# [[ 0.00855706]
#  [-0.00084782]
#  [ 0.00412673]
#  [ 0.00439149]]
# --The norm of the gradient vector |g(x_7723)|: 0.010500339554201847
# --The h vector h_7723:
# [[-0.00855706]
#  [ 0.00084782]
#  [-0.00412673]
#  [-0.00439149]]
# --The solution vector x_7724:
# [[ 0.1168799 ]
#  [-0.01165138]
#  [ 0.05761268]
#  [ 0.05883403]]
#
# ****************************************************
# --At iteration: 7724
# --The gradient vector g(x_7724):
# [[ 0.00855522]
#  [-0.00084764]
#  [ 0.00412586]
#  [ 0.00439053]]
# --The norm of the gradient vector |g(x_7724)|: 0.010498079445975863
# --The h vector h_7724:
# [[-0.00855522]
#  [ 0.00084764]
#  [-0.00412586]
#  [-0.00439053]]
# --The solution vector x_7725:
# [[ 0.11687135]
#  [-0.01165053]
#  [ 0.05760855]
#  [ 0.05882964]]
#
# ****************************************************
# --At iteration: 7725
# --The gradient vector g(x_7725):
# [[ 0.00855338]
#  [-0.00084746]
#  [ 0.00412499]
#  [ 0.00438957]]
# --The norm of the gradient vector |g(x_7725)|: 0.010495820138773204
# --The h vector h_7725:
# [[-0.00855338]
#  [ 0.00084746]
#  [-0.00412499]
#  [-0.00438957]]
# --The solution vector x_7726:
# [[ 0.11686279]
#  [-0.01164968]
#  [ 0.05760443]
#  [ 0.05882525]]
#
# ****************************************************
# --At iteration: 7726
# --The gradient vector g(x_7726):
# [[ 0.00855153]
#  [-0.00084728]
#  [ 0.00412412]
#  [ 0.0043886 ]]
# --The norm of the gradient vector |g(x_7726)|: 0.010493561632199902
# --The h vector h_7726:
# [[-0.00855153]
#  [ 0.00084728]
#  [-0.00412412]
#  [-0.0043886 ]]
# --The solution vector x_7727:
# [[ 0.11685424]
#  [-0.01164884]
#  [ 0.05760031]
#  [ 0.05882087]]
#
# ****************************************************
# --At iteration: 7727
# --The gradient vector g(x_7727):
# [[ 0.00854969]
#  [-0.0008471 ]
#  [ 0.00412325]
#  [ 0.00438764]]
# --The norm of the gradient vector |g(x_7727)|: 0.010491303925862228
# --The h vector h_7727:
# [[-0.00854969]
#  [ 0.0008471 ]
#  [-0.00412325]
#  [-0.00438764]]
# --The solution vector x_7728:
# [[ 0.11684569]
#  [-0.01164799]
#  [ 0.05759618]
#  [ 0.05881648]]
#
# ****************************************************
# --At iteration: 7728
# --The gradient vector g(x_7728):
# [[ 0.00854786]
#  [-0.00084692]
#  [ 0.00412239]
#  [ 0.00438668]]
# --The norm of the gradient vector |g(x_7728)|: 0.010489047019366711
# --The h vector h_7728:
# [[-0.00854786]
#  [ 0.00084692]
#  [-0.00412239]
#  [-0.00438668]]
# --The solution vector x_7729:
# [[ 0.11683715]
#  [-0.01164714]
#  [ 0.05759206]
#  [ 0.05881209]]
#
# ****************************************************
# --At iteration: 7729
# --The gradient vector g(x_7729):
# [[ 0.00854602]
#  [-0.00084673]
#  [ 0.00412152]
#  [ 0.00438572]]
# --The norm of the gradient vector |g(x_7729)|: 0.010486790912320118
# --The h vector h_7729:
# [[-0.00854602]
#  [ 0.00084673]
#  [-0.00412152]
#  [-0.00438572]]
# --The solution vector x_7730:
# [[ 0.1168286 ]
#  [-0.0116463 ]
#  [ 0.05758794]
#  [ 0.05880771]]
#
# ****************************************************
# --At iteration: 7730
# --The gradient vector g(x_7730):
# [[ 0.00854418]
#  [-0.00084655]
#  [ 0.00412065]
#  [ 0.00438476]]
# --The norm of the gradient vector |g(x_7730)|: 0.010484535604329466
# --The h vector h_7730:
# [[-0.00854418]
#  [ 0.00084655]
#  [-0.00412065]
#  [-0.00438476]]
# --The solution vector x_7731:
# [[ 0.11682006]
#  [-0.01164545]
#  [ 0.05758382]
#  [ 0.05880332]]
#
# ****************************************************
# --At iteration: 7731
# --The gradient vector g(x_7731):
# [[ 0.00854234]
#  [-0.00084637]
#  [ 0.00411978]
#  [ 0.00438379]]
# --The norm of the gradient vector |g(x_7731)|: 0.010482281095002018
# --The h vector h_7731:
# [[-0.00854234]
#  [ 0.00084637]
#  [-0.00411978]
#  [-0.00438379]]
# --The solution vector x_7732:
# [[ 0.11681151]
#  [-0.0116446 ]
#  [ 0.0575797 ]
#  [ 0.05879894]]
#
# ****************************************************
# --At iteration: 7732
# --The gradient vector g(x_7732):
# [[ 0.0085405 ]
#  [-0.00084619]
#  [ 0.00411892]
#  [ 0.00438283]]
# --The norm of the gradient vector |g(x_7732)|: 0.010480027383945286
# --The h vector h_7732:
# [[-0.0085405 ]
#  [ 0.00084619]
#  [-0.00411892]
#  [-0.00438283]]
# --The solution vector x_7733:
# [[ 0.11680297]
#  [-0.01164376]
#  [ 0.05757558]
#  [ 0.05879455]]
#
# ****************************************************
# --At iteration: 7733
# --The gradient vector g(x_7733):
# [[ 0.00853867]
#  [-0.00084601]
#  [ 0.00411805]
#  [ 0.00438187]]
# --The norm of the gradient vector |g(x_7733)|: 0.010477774470767016
# --The h vector h_7733:
# [[-0.00853867]
#  [ 0.00084601]
#  [-0.00411805]
#  [-0.00438187]]
# --The solution vector x_7734:
# [[ 0.11679443]
#  [-0.01164291]
#  [ 0.05757146]
#  [ 0.05879017]]
#
# ****************************************************
# --At iteration: 7734
# --The gradient vector g(x_7734):
# [[ 0.00853683]
#  [-0.00084583]
#  [ 0.00411719]
#  [ 0.00438091]]
# --The norm of the gradient vector |g(x_7734)|: 0.010475522355075225
# --The h vector h_7734:
# [[-0.00853683]
#  [ 0.00084583]
#  [-0.00411719]
#  [-0.00438091]]
# --The solution vector x_7735:
# [[ 0.1167859 ]
#  [-0.01164207]
#  [ 0.05756734]
#  [ 0.05878579]]
#
# ****************************************************
# --At iteration: 7735
# --The gradient vector g(x_7735):
# [[ 0.008535  ]
#  [-0.00084565]
#  [ 0.00411632]
#  [ 0.00437995]]
# --The norm of the gradient vector |g(x_7735)|: 0.010473271036478153
# --The h vector h_7735:
# [[-0.008535  ]
#  [ 0.00084565]
#  [-0.00411632]
#  [-0.00437995]]
# --The solution vector x_7736:
# [[ 0.11677736]
#  [-0.01164122]
#  [ 0.05756323]
#  [ 0.05878141]]
#
# ****************************************************
# --At iteration: 7736
# --The gradient vector g(x_7736):
# [[ 0.00853316]
#  [-0.00084547]
#  [ 0.00411546]
#  [ 0.004379  ]]
# --The norm of the gradient vector |g(x_7736)|: 0.010471020514584293
# --The h vector h_7736:
# [[-0.00853316]
#  [ 0.00084547]
#  [-0.00411546]
#  [-0.004379  ]]
# --The solution vector x_7737:
# [[ 0.11676883]
#  [-0.01164037]
#  [ 0.05755911]
#  [ 0.05877703]]
#
# ****************************************************
# --At iteration: 7737
# --The gradient vector g(x_7737):
# [[ 0.00853133]
#  [-0.00084529]
#  [ 0.00411459]
#  [ 0.00437804]]
# --The norm of the gradient vector |g(x_7737)|: 0.01046877078900239
# --The h vector h_7737:
# [[-0.00853133]
#  [ 0.00084529]
#  [-0.00411459]
#  [-0.00437804]]
# --The solution vector x_7738:
# [[ 0.1167603 ]
#  [-0.01163953]
#  [ 0.057555  ]
#  [ 0.05877265]]
#
# ****************************************************
# --At iteration: 7738
# --The gradient vector g(x_7738):
# [[ 0.0085295 ]
#  [-0.00084511]
#  [ 0.00411373]
#  [ 0.00437708]]
# --The norm of the gradient vector |g(x_7738)|: 0.010466521859341419
# --The h vector h_7738:
# [[-0.0085295 ]
#  [ 0.00084511]
#  [-0.00411373]
#  [-0.00437708]]
# --The solution vector x_7739:
# [[ 0.11675177]
#  [-0.01163868]
#  [ 0.05755088]
#  [ 0.05876828]]
#
# ****************************************************
# --At iteration: 7739
# --The gradient vector g(x_7739):
# [[ 0.00852766]
#  [-0.00084493]
#  [ 0.00411286]
#  [ 0.00437612]]
# --The norm of the gradient vector |g(x_7739)|: 0.010464273725210622
# --The h vector h_7739:
# [[-0.00852766]
#  [ 0.00084493]
#  [-0.00411286]
#  [-0.00437612]]
# --The solution vector x_7740:
# [[ 0.11674324]
#  [-0.01163784]
#  [ 0.05754677]
#  [ 0.0587639 ]]
#
# ****************************************************
# --At iteration: 7740
# --The gradient vector g(x_7740):
# [[ 0.00852583]
#  [-0.00084475]
#  [ 0.004112  ]
#  [ 0.00437516]]
# --The norm of the gradient vector |g(x_7740)|: 0.010462026386219458
# --The h vector h_7740:
# [[-0.00852583]
#  [ 0.00084475]
#  [-0.004112  ]
#  [-0.00437516]]
# --The solution vector x_7741:
# [[ 0.11673471]
#  [-0.01163699]
#  [ 0.05754266]
#  [ 0.05875953]]
#
# ****************************************************
# --At iteration: 7741
# --The gradient vector g(x_7741):
# [[ 0.008524  ]
#  [-0.00084457]
#  [ 0.00411113]
#  [ 0.00437421]]
# --The norm of the gradient vector |g(x_7741)|: 0.010459779841977657
# --The h vector h_7741:
# [[-0.008524  ]
#  [ 0.00084457]
#  [-0.00411113]
#  [-0.00437421]]
# --The solution vector x_7742:
# [[ 0.11672619]
#  [-0.01163615]
#  [ 0.05753855]
#  [ 0.05875515]]
#
# ****************************************************
# --At iteration: 7742
# --The gradient vector g(x_7742):
# [[ 0.00852217]
#  [-0.00084439]
#  [ 0.00411027]
#  [ 0.00437325]]
# --The norm of the gradient vector |g(x_7742)|: 0.01045753409209518
# --The h vector h_7742:
# [[-0.00852217]
#  [ 0.00084439]
#  [-0.00411027]
#  [-0.00437325]]
# --The solution vector x_7743:
# [[ 0.11671767]
#  [-0.01163531]
#  [ 0.05753444]
#  [ 0.05875078]]
#
# ****************************************************
# --At iteration: 7743
# --The gradient vector g(x_7743):
# [[ 0.00852034]
#  [-0.00084421]
#  [ 0.00410941]
#  [ 0.00437229]]
# --The norm of the gradient vector |g(x_7743)|: 0.010455289136182237
# --The h vector h_7743:
# [[-0.00852034]
#  [ 0.00084421]
#  [-0.00410941]
#  [-0.00437229]]
# --The solution vector x_7744:
# [[ 0.11670915]
#  [-0.01163446]
#  [ 0.05753033]
#  [ 0.05874641]]
#
# ****************************************************
# --At iteration: 7744
# --The gradient vector g(x_7744):
# [[ 0.00851851]
#  [-0.00084403]
#  [ 0.00410854]
#  [ 0.00437133]]
# --The norm of the gradient vector |g(x_7744)|: 0.010453044973849282
# --The h vector h_7744:
# [[-0.00851851]
#  [ 0.00084403]
#  [-0.00410854]
#  [-0.00437133]]
# --The solution vector x_7745:
# [[ 0.11670063]
#  [-0.01163362]
#  [ 0.05752622]
#  [ 0.05874204]]
#
# ****************************************************
# --At iteration: 7745
# --The gradient vector g(x_7745):
# [[ 0.00851668]
#  [-0.00084385]
#  [ 0.00410768]
#  [ 0.00437038]]
# --The norm of the gradient vector |g(x_7745)|: 0.01045080160470701
# --The h vector h_7745:
# [[-0.00851668]
#  [ 0.00084385]
#  [-0.00410768]
#  [-0.00437038]]
# --The solution vector x_7746:
# [[ 0.11669211]
#  [-0.01163277]
#  [ 0.05752211]
#  [ 0.05873766]]
#
# ****************************************************
# --At iteration: 7746
# --The gradient vector g(x_7746):
# [[ 0.00851486]
#  [-0.00084367]
#  [ 0.00410682]
#  [ 0.00436942]]
# --The norm of the gradient vector |g(x_7746)|: 0.010448559028366357
# --The h vector h_7746:
# [[-0.00851486]
#  [ 0.00084367]
#  [-0.00410682]
#  [-0.00436942]]
# --The solution vector x_7747:
# [[ 0.1166836 ]
#  [-0.01163193]
#  [ 0.057518  ]
#  [ 0.0587333 ]]
#
# ****************************************************
# --At iteration: 7747
# --The gradient vector g(x_7747):
# [[ 0.00851303]
#  [-0.00084349]
#  [ 0.00410596]
#  [ 0.00436847]]
# --The norm of the gradient vector |g(x_7747)|: 0.010446317244438511
# --The h vector h_7747:
# [[-0.00851303]
#  [ 0.00084349]
#  [-0.00410596]
#  [-0.00436847]]
# --The solution vector x_7748:
# [[ 0.11667509]
#  [-0.01163109]
#  [ 0.0575139 ]
#  [ 0.05872893]]
#
# ****************************************************
# --At iteration: 7748
# --The gradient vector g(x_7748):
# [[ 0.0085112 ]
#  [-0.00084331]
#  [ 0.0041051 ]
#  [ 0.00436751]]
# --The norm of the gradient vector |g(x_7748)|: 0.010444076252534901
# --The h vector h_7748:
# [[-0.0085112 ]
#  [ 0.00084331]
#  [-0.0041051 ]
#  [-0.00436751]]
# --The solution vector x_7749:
# [[ 0.11666657]
#  [-0.01163024]
#  [ 0.05750979]
#  [ 0.05872456]]
#
# ****************************************************
# --At iteration: 7749
# --The gradient vector g(x_7749):
# [[ 0.00850938]
#  [-0.00084313]
#  [ 0.00410423]
#  [ 0.00436656]]
# --The norm of the gradient vector |g(x_7749)|: 0.010441836052267199
# --The h vector h_7749:
# [[-0.00850938]
#  [ 0.00084313]
#  [-0.00410423]
#  [-0.00436656]]
# --The solution vector x_7750:
# [[ 0.11665806]
#  [-0.0116294 ]
#  [ 0.05750569]
#  [ 0.05872019]]
#
# ****************************************************
# --At iteration: 7750
# --The gradient vector g(x_7750):
# [[ 0.00850755]
#  [-0.00084295]
#  [ 0.00410337]
#  [ 0.0043656 ]]
# --The norm of the gradient vector |g(x_7750)|: 0.01043959664324731
# --The h vector h_7750:
# [[-0.00850755]
#  [ 0.00084295]
#  [-0.00410337]
#  [-0.0043656 ]]
# --The solution vector x_7751:
# [[ 0.11664956]
#  [-0.01162856]
#  [ 0.05750159]
#  [ 0.05871583]]
#
# ****************************************************
# --At iteration: 7751
# --The gradient vector g(x_7751):
# [[ 0.00850573]
#  [-0.00084277]
#  [ 0.00410251]
#  [ 0.00436465]]
# --The norm of the gradient vector |g(x_7751)|: 0.010437358025087396
# --The h vector h_7751:
# [[-0.00850573]
#  [ 0.00084277]
#  [-0.00410251]
#  [-0.00436465]]
# --The solution vector x_7752:
# [[ 0.11664105]
#  [-0.01162771]
#  [ 0.05749748]
#  [ 0.05871146]]
#
# ****************************************************
# --At iteration: 7752
# --The gradient vector g(x_7752):
# [[ 0.0085039 ]
#  [-0.00084259]
#  [ 0.00410165]
#  [ 0.0043637 ]]
# --The norm of the gradient vector |g(x_7752)|: 0.010435120197399863
# --The h vector h_7752:
# [[-0.0085039 ]
#  [ 0.00084259]
#  [-0.00410165]
#  [-0.0043637 ]]
# --The solution vector x_7753:
# [[ 0.11663255]
#  [-0.01162687]
#  [ 0.05749338]
#  [ 0.0587071 ]]
#
# ****************************************************
# --At iteration: 7753
# --The gradient vector g(x_7753):
# [[ 0.00850208]
#  [-0.00084241]
#  [ 0.00410079]
#  [ 0.00436274]]
# --The norm of the gradient vector |g(x_7753)|: 0.010432883159797351
# --The h vector h_7753:
# [[-0.00850208]
#  [ 0.00084241]
#  [-0.00410079]
#  [-0.00436274]]
# --The solution vector x_7754:
# [[ 0.11662405]
#  [-0.01162603]
#  [ 0.05748928]
#  [ 0.05870274]]
#
# ****************************************************
# --At iteration: 7754
# --The gradient vector g(x_7754):
# [[ 0.00850026]
#  [-0.00084223]
#  [ 0.00409993]
#  [ 0.00436179]]
# --The norm of the gradient vector |g(x_7754)|: 0.010430646911892735
# --The h vector h_7754:
# [[-0.00850026]
#  [ 0.00084223]
#  [-0.00409993]
#  [-0.00436179]]
# --The solution vector x_7755:
# [[ 0.11661554]
#  [-0.01162519]
#  [ 0.05748518]
#  [ 0.05869837]]
#
# ****************************************************
# --At iteration: 7755
# --The gradient vector g(x_7755):
# [[ 0.00849844]
#  [-0.00084205]
#  [ 0.00409907]
#  [ 0.00436084]]
# --The norm of the gradient vector |g(x_7755)|: 0.01042841145329915
# --The h vector h_7755:
# [[-0.00849844]
#  [ 0.00084205]
#  [-0.00409907]
#  [-0.00436084]]
# --The solution vector x_7756:
# [[ 0.11660705]
#  [-0.01162435]
#  [ 0.05748108]
#  [ 0.05869401]]
#
# ****************************************************
# --At iteration: 7756
# --The gradient vector g(x_7756):
# [[ 0.00849662]
#  [-0.00084187]
#  [ 0.00409821]
#  [ 0.00435989]]
# --The norm of the gradient vector |g(x_7756)|: 0.010426176783629958
# --The h vector h_7756:
# [[-0.00849662]
#  [ 0.00084187]
#  [-0.00409821]
#  [-0.00435989]]
# --The solution vector x_7757:
# [[ 0.11659855]
#  [-0.0116235 ]
#  [ 0.05747698]
#  [ 0.05868965]]
#
# ****************************************************
# --At iteration: 7757
# --The gradient vector g(x_7757):
# [[ 0.00849479]
#  [-0.00084169]
#  [ 0.00409735]
#  [ 0.00435893]]
# --The norm of the gradient vector |g(x_7757)|: 0.010423942902498779
# --The h vector h_7757:
# [[-0.00849479]
#  [ 0.00084169]
#  [-0.00409735]
#  [-0.00435893]]
# --The solution vector x_7758:
# [[ 0.11659006]
#  [-0.01162266]
#  [ 0.05747289]
#  [ 0.05868529]]
#
# ****************************************************
# --At iteration: 7758
# --The gradient vector g(x_7758):
# [[ 0.00849297]
#  [-0.00084151]
#  [ 0.0040965 ]
#  [ 0.00435798]]
# --The norm of the gradient vector |g(x_7758)|: 0.01042170980951946
# --The h vector h_7758:
# [[-0.00849297]
#  [ 0.00084151]
#  [-0.0040965 ]
#  [-0.00435798]]
# --The solution vector x_7759:
# [[ 0.11658156]
#  [-0.01162182]
#  [ 0.05746879]
#  [ 0.05868094]]
#
# ****************************************************
# --At iteration: 7759
# --The gradient vector g(x_7759):
# [[ 0.00849116]
#  [-0.00084133]
#  [ 0.00409564]
#  [ 0.00435703]]
# --The norm of the gradient vector |g(x_7759)|: 0.010419477504306092
# --The h vector h_7759:
# [[-0.00849116]
#  [ 0.00084133]
#  [-0.00409564]
#  [-0.00435703]]
# --The solution vector x_7760:
# [[ 0.11657307]
#  [-0.01162098]
#  [ 0.05746469]
#  [ 0.05867658]]
#
# ****************************************************
# --At iteration: 7760
# --The gradient vector g(x_7760):
# [[ 0.00848934]
#  [-0.00084115]
#  [ 0.00409478]
#  [ 0.00435608]]
# --The norm of the gradient vector |g(x_7760)|: 0.010417245986473011
# --The h vector h_7760:
# [[-0.00848934]
#  [ 0.00084115]
#  [-0.00409478]
#  [-0.00435608]]
# --The solution vector x_7761:
# [[ 0.11656458]
#  [-0.01162014]
#  [ 0.0574606 ]
#  [ 0.05867222]]
#
# ****************************************************
# --At iteration: 7761
# --The gradient vector g(x_7761):
# [[ 0.00848752]
#  [-0.00084097]
#  [ 0.00409392]
#  [ 0.00435513]]
# --The norm of the gradient vector |g(x_7761)|: 0.0104150152556348
# --The h vector h_7761:
# [[-0.00848752]
#  [ 0.00084097]
#  [-0.00409392]
#  [-0.00435513]]
# --The solution vector x_7762:
# [[ 0.11655609]
#  [-0.0116193 ]
#  [ 0.05745651]
#  [ 0.05866787]]
#
# ****************************************************
# --At iteration: 7762
# --The gradient vector g(x_7762):
# [[ 0.0084857 ]
#  [-0.00084079]
#  [ 0.00409306]
#  [ 0.00435418]]
# --The norm of the gradient vector |g(x_7762)|: 0.010412785311406263
# --The h vector h_7762:
# [[-0.0084857 ]
#  [ 0.00084079]
#  [-0.00409306]
#  [-0.00435418]]
# --The solution vector x_7763:
# [[ 0.11654761]
#  [-0.01161846]
#  [ 0.05745241]
#  [ 0.05866351]]
#
# ****************************************************
# --At iteration: 7763
# --The gradient vector g(x_7763):
# [[ 0.00848388]
#  [-0.00084061]
#  [ 0.00409221]
#  [ 0.00435323]]
# --The norm of the gradient vector |g(x_7763)|: 0.010410556153402466
# --The h vector h_7763:
# [[-0.00848388]
#  [ 0.00084061]
#  [-0.00409221]
#  [-0.00435323]]
# --The solution vector x_7764:
# [[ 0.11653912]
#  [-0.01161762]
#  [ 0.05744832]
#  [ 0.05865916]]
#
# ****************************************************
# --At iteration: 7764
# --The gradient vector g(x_7764):
# [[ 0.00848207]
#  [-0.00084044]
#  [ 0.00409135]
#  [ 0.00435228]]
# --The norm of the gradient vector |g(x_7764)|: 0.01040832778123871
# --The h vector h_7764:
# [[-0.00848207]
#  [ 0.00084044]
#  [-0.00409135]
#  [-0.00435228]]
# --The solution vector x_7765:
# [[ 0.11653064]
#  [-0.01161677]
#  [ 0.05744423]
#  [ 0.05865481]]
#
# ****************************************************
# --At iteration: 7765
# --The gradient vector g(x_7765):
# [[ 0.00848025]
#  [-0.00084026]
#  [ 0.00409049]
#  [ 0.00435133]]
# --The norm of the gradient vector |g(x_7765)|: 0.010406100194530525
# --The h vector h_7765:
# [[-0.00848025]
#  [ 0.00084026]
#  [-0.00409049]
#  [-0.00435133]]
# --The solution vector x_7766:
# [[ 0.11652216]
#  [-0.01161593]
#  [ 0.05744014]
#  [ 0.05865046]]
#
# ****************************************************
# --At iteration: 7766
# --The gradient vector g(x_7766):
# [[ 0.00847844]
#  [-0.00084008]
#  [ 0.00408964]
#  [ 0.00435038]]
# --The norm of the gradient vector |g(x_7766)|: 0.01040387339289369
# --The h vector h_7766:
# [[-0.00847844]
#  [ 0.00084008]
#  [-0.00408964]
#  [-0.00435038]]
# --The solution vector x_7767:
# [[ 0.11651368]
#  [-0.01161509]
#  [ 0.05743605]
#  [ 0.05864611]]
#
# ****************************************************
# --At iteration: 7767
# --The gradient vector g(x_7767):
# [[ 0.00847662]
#  [-0.0008399 ]
#  [ 0.00408878]
#  [ 0.00434943]]
# --The norm of the gradient vector |g(x_7767)|: 0.010401647375944227
# --The h vector h_7767:
# [[-0.00847662]
#  [ 0.0008399 ]
#  [-0.00408878]
#  [-0.00434943]]
# --The solution vector x_7768:
# [[ 0.11650521]
#  [-0.01161425]
#  [ 0.05743196]
#  [ 0.05864176]]
#
# ****************************************************
# --At iteration: 7768
# --The gradient vector g(x_7768):
# [[ 0.00847481]
#  [-0.00083972]
#  [ 0.00408793]
#  [ 0.00434848]]
# --The norm of the gradient vector |g(x_7768)|: 0.010399422143298398
# --The h vector h_7768:
# [[-0.00847481]
#  [ 0.00083972]
#  [-0.00408793]
#  [-0.00434848]]
# --The solution vector x_7769:
# [[ 0.11649673]
#  [-0.01161341]
#  [ 0.05742787]
#  [ 0.05863741]]
#
# ****************************************************
# --At iteration: 7769
# --The gradient vector g(x_7769):
# [[ 0.008473  ]
#  [-0.00083954]
#  [ 0.00408707]
#  [ 0.00434754]]
# --The norm of the gradient vector |g(x_7769)|: 0.010397197694572691
# --The h vector h_7769:
# [[-0.008473  ]
#  [ 0.00083954]
#  [-0.00408707]
#  [-0.00434754]]
# --The solution vector x_7770:
# [[ 0.11648826]
#  [-0.01161258]
#  [ 0.05742379]
#  [ 0.05863306]]
#
# ****************************************************
# --At iteration: 7770
# --The gradient vector g(x_7770):
# [[ 0.00847118]
#  [-0.00083936]
#  [ 0.00408621]
#  [ 0.00434659]]
# --The norm of the gradient vector |g(x_7770)|: 0.010394974029383854
# --The h vector h_7770:
# [[-0.00847118]
#  [ 0.00083936]
#  [-0.00408621]
#  [-0.00434659]]
# --The solution vector x_7771:
# [[ 0.11647979]
#  [-0.01161174]
#  [ 0.0574197 ]
#  [ 0.05862871]]
#
# ****************************************************
# --At iteration: 7771
# --The gradient vector g(x_7771):
# [[ 0.00846937]
#  [-0.00083919]
#  [ 0.00408536]
#  [ 0.00434564]]
# --The norm of the gradient vector |g(x_7771)|: 0.010392751147348852
# --The h vector h_7771:
# [[-0.00846937]
#  [ 0.00083919]
#  [-0.00408536]
#  [-0.00434564]]
# --The solution vector x_7772:
# [[ 0.11647132]
#  [-0.0116109 ]
#  [ 0.05741561]
#  [ 0.05862437]]
#
# ****************************************************
# --At iteration: 7772
# --The gradient vector g(x_7772):
# [[ 0.00846756]
#  [-0.00083901]
#  [ 0.00408451]
#  [ 0.0043447 ]]
# --The norm of the gradient vector |g(x_7772)|: 0.010390529048084915
# --The h vector h_7772:
# [[-0.00846756]
#  [ 0.00083901]
#  [-0.00408451]
#  [-0.0043447 ]]
# --The solution vector x_7773:
# [[ 0.11646285]
#  [-0.01161006]
#  [ 0.05741153]
#  [ 0.05862002]]
#
# ****************************************************
# --At iteration: 7773
# --The gradient vector g(x_7773):
# [[ 0.00846575]
#  [-0.00083883]
#  [ 0.00408365]
#  [ 0.00434375]]
# --The norm of the gradient vector |g(x_7773)|: 0.010388307731209486
# --The h vector h_7773:
# [[-0.00846575]
#  [ 0.00083883]
#  [-0.00408365]
#  [-0.00434375]]
# --The solution vector x_7774:
# [[ 0.11645439]
#  [-0.01160922]
#  [ 0.05740745]
#  [ 0.05861568]]
#
# ****************************************************
# --At iteration: 7774
# --The gradient vector g(x_7774):
# [[ 0.00846394]
#  [-0.00083865]
#  [ 0.0040828 ]
#  [ 0.0043428 ]]
# --The norm of the gradient vector |g(x_7774)|: 0.010386087196340257
# --The h vector h_7774:
# [[-0.00846394]
#  [ 0.00083865]
#  [-0.0040828 ]
#  [-0.0043428 ]]
# --The solution vector x_7775:
# [[ 0.11644592]
#  [-0.01160838]
#  [ 0.05740336]
#  [ 0.05861134]]
#
# ****************************************************
# --At iteration: 7775
# --The gradient vector g(x_7775):
# [[ 0.00846213]
#  [-0.00083847]
#  [ 0.00408194]
#  [ 0.00434186]]
# --The norm of the gradient vector |g(x_7775)|: 0.010383867443095166
# --The h vector h_7775:
# [[-0.00846213]
#  [ 0.00083847]
#  [-0.00408194]
#  [-0.00434186]]
# --The solution vector x_7776:
# [[ 0.11643746]
#  [-0.01160754]
#  [ 0.05739928]
#  [ 0.058607  ]]
#
# ****************************************************
# --At iteration: 7776
# --The gradient vector g(x_7776):
# [[ 0.00846032]
#  [-0.00083829]
#  [ 0.00408109]
#  [ 0.00434091]]
# --The norm of the gradient vector |g(x_7776)|: 0.010381648471092382
# --The h vector h_7776:
# [[-0.00846032]
#  [ 0.00083829]
#  [-0.00408109]
#  [-0.00434091]]
# --The solution vector x_7777:
# [[ 0.116429  ]
#  [-0.0116067 ]
#  [ 0.0573952 ]
#  [ 0.05860266]]
#
# ****************************************************
# --At iteration: 7777
# --The gradient vector g(x_7777):
# [[ 0.00845852]
#  [-0.00083812]
#  [ 0.00408024]
#  [ 0.00433997]]
# --The norm of the gradient vector |g(x_7777)|: 0.010379430279950313
# --The h vector h_7777:
# [[-0.00845852]
#  [ 0.00083812]
#  [-0.00408024]
#  [-0.00433997]]
# --The solution vector x_7778:
# [[ 0.11642054]
#  [-0.01160587]
#  [ 0.05739112]
#  [ 0.05859832]]
#
# ****************************************************
# --At iteration: 7778
# --The gradient vector g(x_7778):
# [[ 0.00845671]
#  [-0.00083794]
#  [ 0.00407938]
#  [ 0.00433902]]
# --The norm of the gradient vector |g(x_7778)|: 0.0103772128692876
# --The h vector h_7778:
# [[-0.00845671]
#  [ 0.00083794]
#  [-0.00407938]
#  [-0.00433902]]
# --The solution vector x_7779:
# [[ 0.11641208]
#  [-0.01160503]
#  [ 0.05738704]
#  [ 0.05859398]]
#
# ****************************************************
# --At iteration: 7779
# --The gradient vector g(x_7779):
# [[ 0.0084549 ]
#  [-0.00083776]
#  [ 0.00407853]
#  [ 0.00433808]]
# --The norm of the gradient vector |g(x_7779)|: 0.01037499623872314
# --The h vector h_7779:
# [[-0.0084549 ]
#  [ 0.00083776]
#  [-0.00407853]
#  [-0.00433808]]
# --The solution vector x_7780:
# [[ 0.11640363]
#  [-0.01160419]
#  [ 0.05738296]
#  [ 0.05858964]]
#
# ****************************************************
# --At iteration: 7780
# --The gradient vector g(x_7780):
# [[ 0.0084531 ]
#  [-0.00083758]
#  [ 0.00407768]
#  [ 0.00433713]]
# --The norm of the gradient vector |g(x_7780)|: 0.01037278038787604
# --The h vector h_7780:
# [[-0.0084531 ]
#  [ 0.00083758]
#  [-0.00407768]
#  [-0.00433713]]
# --The solution vector x_7781:
# [[ 0.11639518]
#  [-0.01160335]
#  [ 0.05737888]
#  [ 0.0585853 ]]
#
# ****************************************************
# --At iteration: 7781
# --The gradient vector g(x_7781):
# [[ 0.00845129]
#  [-0.0008374 ]
#  [ 0.00407683]
#  [ 0.00433619]]
# --The norm of the gradient vector |g(x_7781)|: 0.010370565316365665
# --The h vector h_7781:
# [[-0.00845129]
#  [ 0.0008374 ]
#  [-0.00407683]
#  [-0.00433619]]
# --The solution vector x_7782:
# [[ 0.11638672]
#  [-0.01160251]
#  [ 0.05737481]
#  [ 0.05858096]]
#
# ****************************************************
# --At iteration: 7782
# --The gradient vector g(x_7782):
# [[ 0.00844949]
#  [-0.00083723]
#  [ 0.00407598]
#  [ 0.00433525]]
# --The norm of the gradient vector |g(x_7782)|: 0.010368351023811612
# --The h vector h_7782:
# [[-0.00844949]
#  [ 0.00083723]
#  [-0.00407598]
#  [-0.00433525]]
# --The solution vector x_7783:
# [[ 0.11637828]
#  [-0.01160168]
#  [ 0.05737073]
#  [ 0.05857663]]
#
# ****************************************************
# --At iteration: 7783
# --The gradient vector g(x_7783):
# [[ 0.00844768]
#  [-0.00083705]
#  [ 0.00407512]
#  [ 0.0043343 ]]
# --The norm of the gradient vector |g(x_7783)|: 0.01036613750983371
# --The h vector h_7783:
# [[-0.00844768]
#  [ 0.00083705]
#  [-0.00407512]
#  [-0.0043343 ]]
# --The solution vector x_7784:
# [[ 0.11636983]
#  [-0.01160084]
#  [ 0.05736666]
#  [ 0.0585723 ]]
#
# ****************************************************
# --At iteration: 7784
# --The gradient vector g(x_7784):
# [[ 0.00844588]
#  [-0.00083687]
#  [ 0.00407427]
#  [ 0.00433336]]
# --The norm of the gradient vector |g(x_7784)|: 0.010363924774052038
# --The h vector h_7784:
# [[-0.00844588]
#  [ 0.00083687]
#  [-0.00407427]
#  [-0.00433336]]
# --The solution vector x_7785:
# [[ 0.11636138]
#  [-0.0116    ]
#  [ 0.05736258]
#  [ 0.05856796]]
#
# ****************************************************
# --At iteration: 7785
# --The gradient vector g(x_7785):
# [[ 0.00844408]
#  [-0.00083669]
#  [ 0.00407342]
#  [ 0.00433242]]
# --The norm of the gradient vector |g(x_7785)|: 0.010361712816086895
# --The h vector h_7785:
# [[-0.00844408]
#  [ 0.00083669]
#  [-0.00407342]
#  [-0.00433242]]
# --The solution vector x_7786:
# [[ 0.11635294]
#  [-0.01159917]
#  [ 0.05735851]
#  [ 0.05856363]]
#
# ****************************************************
# --At iteration: 7786
# --The gradient vector g(x_7786):
# [[ 0.00844227]
#  [-0.00083652]
#  [ 0.00407257]
#  [ 0.00433148]]
# --The norm of the gradient vector |g(x_7786)|: 0.010359501635558826
# --The h vector h_7786:
# [[-0.00844227]
#  [ 0.00083652]
#  [-0.00407257]
#  [-0.00433148]]
# --The solution vector x_7787:
# [[ 0.1163445 ]
#  [-0.01159833]
#  [ 0.05735444]
#  [ 0.0585593 ]]
#
# ****************************************************
# --At iteration: 7787
# --The gradient vector g(x_7787):
# [[ 0.00844047]
#  [-0.00083634]
#  [ 0.00407172]
#  [ 0.00433053]]
# --The norm of the gradient vector |g(x_7787)|: 0.01035729123208862
# --The h vector h_7787:
# [[-0.00844047]
#  [ 0.00083634]
#  [-0.00407172]
#  [-0.00433053]]
# --The solution vector x_7788:
# [[ 0.11633605]
#  [-0.01159749]
#  [ 0.05735036]
#  [ 0.05855497]]
#
# ****************************************************
# --At iteration: 7788
# --The gradient vector g(x_7788):
# [[ 0.00843867]
#  [-0.00083616]
#  [ 0.00407087]
#  [ 0.00432959]]
# --The norm of the gradient vector |g(x_7788)|: 0.01035508160529728
# --The h vector h_7788:
# [[-0.00843867]
#  [ 0.00083616]
#  [-0.00407087]
#  [-0.00432959]]
# --The solution vector x_7789:
# [[ 0.11632762]
#  [-0.01159666]
#  [ 0.05734629]
#  [ 0.05855064]]
#
# ****************************************************
# --At iteration: 7789
# --The gradient vector g(x_7789):
# [[ 0.00843687]
#  [-0.00083598]
#  [ 0.00407002]
#  [ 0.00432865]]
# --The norm of the gradient vector |g(x_7789)|: 0.010352872754806062
# --The h vector h_7789:
# [[-0.00843687]
#  [ 0.00083598]
#  [-0.00407002]
#  [-0.00432865]]
# --The solution vector x_7790:
# [[ 0.11631918]
#  [-0.01159582]
#  [ 0.05734222]
#  [ 0.05854631]]
#
# ****************************************************
# --At iteration: 7790
# --The gradient vector g(x_7790):
# [[ 0.00843507]
#  [-0.00083581]
#  [ 0.00406917]
#  [ 0.00432771]]
# --The norm of the gradient vector |g(x_7790)|: 0.010350664680236458
# --The h vector h_7790:
# [[-0.00843507]
#  [ 0.00083581]
#  [-0.00406917]
#  [-0.00432771]]
# --The solution vector x_7791:
# [[ 0.11631074]
#  [-0.01159499]
#  [ 0.05733815]
#  [ 0.05854198]]
#
# ****************************************************
# --At iteration: 7791
# --The gradient vector g(x_7791):
# [[ 0.00843327]
#  [-0.00083563]
#  [ 0.00406832]
#  [ 0.00432677]]
# --The norm of the gradient vector |g(x_7791)|: 0.01034845738121019
# --The h vector h_7791:
# [[-0.00843327]
#  [ 0.00083563]
#  [-0.00406832]
#  [-0.00432677]]
# --The solution vector x_7792:
# [[ 0.11630231]
#  [-0.01159415]
#  [ 0.05733409]
#  [ 0.05853765]]
#
# ****************************************************
# --At iteration: 7792
# --The gradient vector g(x_7792):
# [[ 0.00843147]
#  [-0.00083545]
#  [ 0.00406748]
#  [ 0.00432583]]
# --The norm of the gradient vector |g(x_7792)|: 0.010346250857349219
# --The h vector h_7792:
# [[-0.00843147]
#  [ 0.00083545]
#  [-0.00406748]
#  [-0.00432583]]
# --The solution vector x_7793:
# [[ 0.11629388]
#  [-0.01159331]
#  [ 0.05733002]
#  [ 0.05853333]]
#
# ****************************************************
# --At iteration: 7793
# --The gradient vector g(x_7793):
# [[ 0.00842968]
#  [-0.00083528]
#  [ 0.00406663]
#  [ 0.00432489]]
# --The norm of the gradient vector |g(x_7793)|: 0.010344045108275733
# --The h vector h_7793:
# [[-0.00842968]
#  [ 0.00083528]
#  [-0.00406663]
#  [-0.00432489]]
# --The solution vector x_7794:
# [[ 0.11628545]
#  [-0.01159248]
#  [ 0.05732595]
#  [ 0.058529  ]]
#
# ****************************************************
# --At iteration: 7794
# --The gradient vector g(x_7794):
# [[ 0.00842788]
#  [-0.0008351 ]
#  [ 0.00406578]
#  [ 0.00432395]]
# --The norm of the gradient vector |g(x_7794)|: 0.010341840133612166
# --The h vector h_7794:
# [[-0.00842788]
#  [ 0.0008351 ]
#  [-0.00406578]
#  [-0.00432395]]
# --The solution vector x_7795:
# [[ 0.11627702]
#  [-0.01159164]
#  [ 0.05732189]
#  [ 0.05852468]]
#
# ****************************************************
# --At iteration: 7795
# --The gradient vector g(x_7795):
# [[ 0.00842608]
#  [-0.00083492]
#  [ 0.00406493]
#  [ 0.00432301]]
# --The norm of the gradient vector |g(x_7795)|: 0.010339635932981178
# --The h vector h_7795:
# [[-0.00842608]
#  [ 0.00083492]
#  [-0.00406493]
#  [-0.00432301]]
# --The solution vector x_7796:
# [[ 0.1162686 ]
#  [-0.01159081]
#  [ 0.05731782]
#  [ 0.05852036]]
#
# ****************************************************
# --At iteration: 7796
# --The gradient vector g(x_7796):
# [[ 0.00842429]
#  [-0.00083475]
#  [ 0.00406408]
#  [ 0.00432207]]
# --The norm of the gradient vector |g(x_7796)|: 0.010337432506005672
# --The h vector h_7796:
# [[-0.00842429]
#  [ 0.00083475]
#  [-0.00406408]
#  [-0.00432207]]
# --The solution vector x_7797:
# [[ 0.11626017]
#  [-0.01158997]
#  [ 0.05731376]
#  [ 0.05851604]]
#
# ****************************************************
# --At iteration: 7797
# --The gradient vector g(x_7797):
# [[ 0.00842249]
#  [-0.00083457]
#  [ 0.00406324]
#  [ 0.00432113]]
# --The norm of the gradient vector |g(x_7797)|: 0.010335229852308782
# --The h vector h_7797:
# [[-0.00842249]
#  [ 0.00083457]
#  [-0.00406324]
#  [-0.00432113]]
# --The solution vector x_7798:
# [[ 0.11625175]
#  [-0.01158914]
#  [ 0.05730969]
#  [ 0.05851171]]
#
# ****************************************************
# --At iteration: 7798
# --The gradient vector g(x_7798):
# [[ 0.0084207 ]
#  [-0.00083439]
#  [ 0.00406239]
#  [ 0.0043202 ]]
# --The norm of the gradient vector |g(x_7798)|: 0.010333027971513876
# --The h vector h_7798:
# [[-0.0084207 ]
#  [ 0.00083439]
#  [-0.00406239]
#  [-0.0043202 ]]
# --The solution vector x_7799:
# [[ 0.11624333]
#  [-0.01158831]
#  [ 0.05730563]
#  [ 0.05850739]]
#
# ****************************************************
# --At iteration: 7799
# --The gradient vector g(x_7799):
# [[ 0.0084189 ]
#  [-0.00083421]
#  [ 0.00406154]
#  [ 0.00431926]]
# --The norm of the gradient vector |g(x_7799)|: 0.010330826863244552
# --The h vector h_7799:
# [[-0.0084189 ]
#  [ 0.00083421]
#  [-0.00406154]
#  [-0.00431926]]
# --The solution vector x_7800:
# [[ 0.11623491]
#  [-0.01158747]
#  [ 0.05730157]
#  [ 0.05850307]]
#
# ****************************************************
# --At iteration: 7800
# --The gradient vector g(x_7800):
# [[ 0.00841711]
#  [-0.00083404]
#  [ 0.0040607 ]
#  [ 0.00431832]]
# --The norm of the gradient vector |g(x_7800)|: 0.010328626527124659
# --The h vector h_7800:
# [[-0.00841711]
#  [ 0.00083404]
#  [-0.0040607 ]
#  [-0.00431832]]
# --The solution vector x_7801:
# [[ 0.11622649]
#  [-0.01158664]
#  [ 0.05729751]
#  [ 0.05849876]]
#
# ****************************************************
# --At iteration: 7801
# --The gradient vector g(x_7801):
# [[ 0.00841532]
#  [-0.00083386]
#  [ 0.00405985]
#  [ 0.00431738]]
# --The norm of the gradient vector |g(x_7801)|: 0.010326426962778251
# --The h vector h_7801:
# [[-0.00841532]
#  [ 0.00083386]
#  [-0.00405985]
#  [-0.00431738]]
# --The solution vector x_7802:
# [[ 0.11621808]
#  [-0.0115858 ]
#  [ 0.05729345]
#  [ 0.05849444]]
#
# ****************************************************
# --At iteration: 7802
# --The gradient vector g(x_7802):
# [[ 0.00841353]
#  [-0.00083369]
#  [ 0.004059  ]
#  [ 0.00431645]]
# --The norm of the gradient vector |g(x_7802)|: 0.01032422816982964
# --The h vector h_7802:
# [[-0.00841353]
#  [ 0.00083369]
#  [-0.004059  ]
#  [-0.00431645]]
# --The solution vector x_7803:
# [[ 0.11620966]
#  [-0.01158497]
#  [ 0.05728939]
#  [ 0.05849012]]
#
# ****************************************************
# --At iteration: 7803
# --The gradient vector g(x_7803):
# [[ 0.00841173]
#  [-0.00083351]
#  [ 0.00405816]
#  [ 0.00431551]]
# --The norm of the gradient vector |g(x_7803)|: 0.010322030147903366
# --The h vector h_7803:
# [[-0.00841173]
#  [ 0.00083351]
#  [-0.00405816]
#  [-0.00431551]]
# --The solution vector x_7804:
# [[ 0.11620125]
#  [-0.01158414]
#  [ 0.05728533]
#  [ 0.05848581]]
#
# ****************************************************
# --At iteration: 7804
# --The gradient vector g(x_7804):
# [[ 0.00840994]
#  [-0.00083333]
#  [ 0.00405731]
#  [ 0.00431458]]
# --The norm of the gradient vector |g(x_7804)|: 0.01031983289662419
# --The h vector h_7804:
# [[-0.00840994]
#  [ 0.00083333]
#  [-0.00405731]
#  [-0.00431458]]
# --The solution vector x_7805:
# [[ 0.11619284]
#  [-0.0115833 ]
#  [ 0.05728127]
#  [ 0.05848149]]
#
# ****************************************************
# --At iteration: 7805
# --The gradient vector g(x_7805):
# [[ 0.00840815]
#  [-0.00083316]
#  [ 0.00405647]
#  [ 0.00431364]]
# --The norm of the gradient vector |g(x_7805)|: 0.01031763641561713
# --The h vector h_7805:
# [[-0.00840815]
#  [ 0.00083316]
#  [-0.00405647]
#  [-0.00431364]]
# --The solution vector x_7806:
# [[ 0.11618443]
#  [-0.01158247]
#  [ 0.05727722]
#  [ 0.05847718]]
#
# ****************************************************
# --At iteration: 7806
# --The gradient vector g(x_7806):
# [[ 0.00840636]
#  [-0.00083298]
#  [ 0.00405562]
#  [ 0.0043127 ]]
# --The norm of the gradient vector |g(x_7806)|: 0.010315440704507415
# --The h vector h_7806:
# [[-0.00840636]
#  [ 0.00083298]
#  [-0.00405562]
#  [-0.0043127 ]]
# --The solution vector x_7807:
# [[ 0.11617603]
#  [-0.01158164]
# ...
#
# ****************************************************
# --At iteration: 7916
# --The gradient vector g(x_7916):
# [[ 0.00821328]
#  [-0.00081396]
#  [ 0.00396445]
#  [ 0.00421182]]
# --The norm of the gradient vector |g(x_7916)|: 0.010078528764513529
# --The h vector h_7916:
# [[-0.00821328]
#  [ 0.00081396]
#  [-0.00396445]
#  [-0.00421182]]
# --The solution vector x_7917:
# [[ 0.11526211]
#  [-0.01149107]
#  [ 0.05683214]
#  [ 0.0580041 ]]
#
# ****************************************************
# --At iteration: 7917
# --The gradient vector g(x_7917):
# [[ 0.00821156]
#  [-0.00081379]
#  [ 0.00396364]
#  [ 0.00421092]]
# --The norm of the gradient vector |g(x_7917)|: 0.010076416235882893
# --The h vector h_7917:
# [[-0.00821156]
#  [ 0.00081379]
#  [-0.00396364]
#  [-0.00421092]]
# --The solution vector x_7918:
# [[ 0.1152539 ]
#  [-0.01149026]
#  [ 0.05682817]
#  [ 0.05799989]]
#
# ****************************************************
# --At iteration: 7918
# --The gradient vector g(x_7918):
# [[ 0.00820983]
#  [-0.00081362]
#  [ 0.00396283]
#  [ 0.00421002]]
# --The norm of the gradient vector |g(x_7918)|: 0.010074304436609243
# --The h vector h_7918:
# [[-0.00820983]
#  [ 0.00081362]
#  [-0.00396283]
#  [-0.00421002]]
# --The solution vector x_7919:
# [[ 0.11524569]
#  [-0.01148944]
#  [ 0.05682421]
#  [ 0.05799568]]
#
# ****************************************************
# --At iteration: 7919
# --The gradient vector g(x_7919):
# [[ 0.00820811]
#  [-0.00081345]
#  [ 0.00396201]
#  [ 0.00420912]]
# --The norm of the gradient vector |g(x_7919)|: 0.010072193366343045
# --The h vector h_7919:
# [[-0.00820811]
#  [ 0.00081345]
#  [-0.00396201]
#  [-0.00420912]]
# --The solution vector x_7920:
# [[ 0.11523748]
#  [-0.01148863]
#  [ 0.05682025]
#  [ 0.05799147]]
#
# ****************************************************
# --At iteration: 7920
# --The gradient vector g(x_7920):
# [[ 0.00820639]
#  [-0.00081328]
#  [ 0.0039612 ]
#  [ 0.00420822]]
# --The norm of the gradient vector |g(x_7920)|: 0.010070083024734975
# --The h vector h_7920:
# [[-0.00820639]
#  [ 0.00081328]
#  [-0.0039612 ]
#  [-0.00420822]]
# --The solution vector x_7921:
# [[ 0.11522928]
#  [-0.01148782]
#  [ 0.05681629]
#  [ 0.05798727]]
#
# ****************************************************
# --At iteration: 7921
# --The gradient vector g(x_7921):
# [[ 0.00820467]
#  [-0.00081311]
#  [ 0.00396039]
#  [ 0.00420732]]
# --The norm of the gradient vector |g(x_7921)|: 0.010067973411435937
# --The h vector h_7921:
# [[-0.00820467]
#  [ 0.00081311]
#  [-0.00396039]
#  [-0.00420732]]
# --The solution vector x_7922:
# [[ 0.11522107]
#  [-0.011487  ]
#  [ 0.05681233]
#  [ 0.05798306]]
#
# ****************************************************
# --At iteration: 7922
# --The gradient vector g(x_7922):
# [[ 0.00820296]
#  [-0.00081294]
#  [ 0.00395958]
#  [ 0.00420643]]
# --The norm of the gradient vector |g(x_7922)|: 0.010065864526097033
# --The h vector h_7922:
# [[-0.00820296]
#  [ 0.00081294]
#  [-0.00395958]
#  [-0.00420643]]
# --The solution vector x_7923:
# [[ 0.11521287]
#  [-0.01148619]
#  [ 0.05680837]
#  [ 0.05797885]]
#
# ****************************************************
# --At iteration: 7923
# --The gradient vector g(x_7923):
# [[ 0.00820124]
#  [-0.00081277]
#  [ 0.00395877]
#  [ 0.00420553]]
# --The norm of the gradient vector |g(x_7923)|: 0.010063756368369599
# --The h vector h_7923:
# [[-0.00820124]
#  [ 0.00081277]
#  [-0.00395877]
#  [-0.00420553]]
# --The solution vector x_7924:
# [[ 0.11520467]
#  [-0.01148538]
#  [ 0.05680441]
#  [ 0.05797465]]
#
# ****************************************************
# --At iteration: 7924
# --The gradient vector g(x_7924):
# [[ 0.00819952]
#  [-0.0008126 ]
#  [ 0.00395795]
#  [ 0.00420463]]
# --The norm of the gradient vector |g(x_7924)|: 0.010061648937905157
# --The h vector h_7924:
# [[-0.00819952]
#  [ 0.0008126 ]
#  [-0.00395795]
#  [-0.00420463]]
# --The solution vector x_7925:
# [[ 0.11519647]
#  [-0.01148457]
#  [ 0.05680045]
#  [ 0.05797044]]
#
# ****************************************************
# --At iteration: 7925
# --The gradient vector g(x_7925):
# [[ 0.0081978 ]
#  [-0.00081243]
#  [ 0.00395714]
#  [ 0.00420373]]
# --The norm of the gradient vector |g(x_7925)|: 0.010059542234355465
# --The h vector h_7925:
# [[-0.0081978 ]
#  [ 0.00081243]
#  [-0.00395714]
#  [-0.00420373]]
# --The solution vector x_7926:
# [[ 0.11518827]
#  [-0.01148375]
#  [ 0.05679649]
#  [ 0.05796624]]
#
# ****************************************************
# --At iteration: 7926
# --The gradient vector g(x_7926):
# [[ 0.00819609]
#  [-0.00081226]
#  [ 0.00395633]
#  [ 0.00420284]]
# --The norm of the gradient vector |g(x_7926)|: 0.010057436257372489
# --The h vector h_7926:
# [[-0.00819609]
#  [ 0.00081226]
#  [-0.00395633]
#  [-0.00420284]]
# --The solution vector x_7927:
# [[ 0.11518007]
#  [-0.01148294]
#  [ 0.05679254]
#  [ 0.05796203]]
#
# ****************************************************
# --At iteration: 7927
# --The gradient vector g(x_7927):
# [[ 0.00819437]
#  [-0.0008121 ]
#  [ 0.00395552]
#  [ 0.00420194]]
# --The norm of the gradient vector |g(x_7927)|: 0.010055331006608392
# --The h vector h_7927:
# [[-0.00819437]
#  [ 0.0008121 ]
#  [-0.00395552]
#  [-0.00420194]]
# --The solution vector x_7928:
# [[ 0.11517188]
#  [-0.01148213]
#  [ 0.05678858]
#  [ 0.05795783]]
#
# ****************************************************
# --At iteration: 7928
# --The gradient vector g(x_7928):
# [[ 0.00819266]
#  [-0.00081193]
#  [ 0.00395471]
#  [ 0.00420105]]
# --The norm of the gradient vector |g(x_7928)|: 0.010053226481715574
# --The h vector h_7928:
# [[-0.00819266]
#  [ 0.00081193]
#  [-0.00395471]
#  [-0.00420105]]
# --The solution vector x_7929:
# [[ 0.11516369]
#  [-0.01148132]
#  [ 0.05678463]
#  [ 0.05795363]]
#
# ****************************************************
# --At iteration: 7929
# --The gradient vector g(x_7929):
# [[ 0.00819094]
#  [-0.00081176]
#  [ 0.0039539 ]
#  [ 0.00420015]]
# --The norm of the gradient vector |g(x_7929)|: 0.010051122682346628
# --The h vector h_7929:
# [[-0.00819094]
#  [ 0.00081176]
#  [-0.0039539 ]
#  [-0.00420015]]
# --The solution vector x_7930:
# [[ 0.1151555 ]
#  [-0.01148051]
#  [ 0.05678067]
#  [ 0.05794943]]
#
# ****************************************************
# --At iteration: 7930
# --The gradient vector g(x_7930):
# [[ 0.00818923]
#  [-0.00081159]
#  [ 0.00395309]
#  [ 0.00419926]]
# --The norm of the gradient vector |g(x_7930)|: 0.01004901960815437
# --The h vector h_7930:
# [[-0.00818923]
#  [ 0.00081159]
#  [-0.00395309]
#  [-0.00419926]]
# --The solution vector x_7931:
# [[ 0.11514731]
#  [-0.01147969]
#  [ 0.05677672]
#  [ 0.05794523]]
#
# ****************************************************
# --At iteration: 7931
# --The gradient vector g(x_7931):
# [[ 0.00818751]
#  [-0.00081142]
#  [ 0.00395228]
#  [ 0.00419836]]
# --The norm of the gradient vector |g(x_7931)|: 0.010046917258791825
# --The h vector h_7931:
# [[-0.00818751]
#  [ 0.00081142]
#  [-0.00395228]
#  [-0.00419836]]
# --The solution vector x_7932:
# [[ 0.11513912]
#  [-0.01147888]
#  [ 0.05677277]
#  [ 0.05794103]]
#
# ****************************************************
# --At iteration: 7932
# --The gradient vector g(x_7932):
# [[ 0.0081858 ]
#  [-0.00081125]
#  [ 0.00395147]
#  [ 0.00419747]]
# --The norm of the gradient vector |g(x_7932)|: 0.010044815633912229
# --The h vector h_7932:
# [[-0.0081858 ]
#  [ 0.00081125]
#  [-0.00395147]
#  [-0.00419747]]
# --The solution vector x_7933:
# [[ 0.11513093]
#  [-0.01147807]
#  [ 0.05676881]
#  [ 0.05793684]]
#
# ****************************************************
# --At iteration: 7933
# --The gradient vector g(x_7933):
# [[ 0.00818409]
#  [-0.00081108]
#  [ 0.00395066]
#  [ 0.00419657]]
# --The norm of the gradient vector |g(x_7933)|: 0.01004271473316903
# --The h vector h_7933:
# [[-0.00818409]
#  [ 0.00081108]
#  [-0.00395066]
#  [-0.00419657]]
# --The solution vector x_7934:
# [[ 0.11512275]
#  [-0.01147726]
#  [ 0.05676486]
#  [ 0.05793264]]
#
# ****************************************************
# --At iteration: 7934
# --The gradient vector g(x_7934):
# [[ 0.00818238]
#  [-0.00081091]
#  [ 0.00394986]
#  [ 0.00419568]]
# --The norm of the gradient vector |g(x_7934)|: 0.01004061455621589
# --The h vector h_7934:
# [[-0.00818238]
#  [ 0.00081091]
#  [-0.00394986]
#  [-0.00419568]]
# --The solution vector x_7935:
# [[ 0.11511457]
#  [-0.01147645]
#  [ 0.05676091]
#  [ 0.05792844]]
#
# ****************************************************
# --At iteration: 7935
# --The gradient vector g(x_7935):
# [[ 0.00818067]
#  [-0.00081075]
#  [ 0.00394905]
#  [ 0.00419478]]
# --The norm of the gradient vector |g(x_7935)|: 0.010038515102706683
# --The h vector h_7935:
# [[-0.00818067]
#  [ 0.00081075]
#  [-0.00394905]
#  [-0.00419478]]
# --The solution vector x_7936:
# [[ 0.11510639]
#  [-0.01147564]
#  [ 0.05675696]
#  [ 0.05792425]]
#
# ****************************************************
# --At iteration: 7936
# --The gradient vector g(x_7936):
# [[ 0.00817895]
#  [-0.00081058]
#  [ 0.00394824]
#  [ 0.00419389]]
# --The norm of the gradient vector |g(x_7936)|: 0.01003641637229549
# --The h vector h_7936:
# [[-0.00817895]
#  [ 0.00081058]
#  [-0.00394824]
#  [-0.00419389]]
# --The solution vector x_7937:
# [[ 0.11509821]
#  [-0.01147483]
#  [ 0.05675302]
#  [ 0.05792006]]
#
# ****************************************************
# --At iteration: 7937
# --The gradient vector g(x_7937):
# [[ 0.00817725]
#  [-0.00081041]
#  [ 0.00394743]
#  [ 0.004193  ]]
# --The norm of the gradient vector |g(x_7937)|: 0.010034318364636604
# --The h vector h_7937:
# [[-0.00817725]
#  [ 0.00081041]
#  [-0.00394743]
#  [-0.004193  ]]
# --The solution vector x_7938:
# [[ 0.11509003]
#  [-0.01147402]
#  [ 0.05674907]
#  [ 0.05791586]]
#
# ****************************************************
# --At iteration: 7938
# --The gradient vector g(x_7938):
# [[ 0.00817554]
#  [-0.00081024]
#  [ 0.00394662]
#  [ 0.00419211]]
# --The norm of the gradient vector |g(x_7938)|: 0.010032221079384535
# --The h vector h_7938:
# [[-0.00817554]
#  [ 0.00081024]
#  [-0.00394662]
#  [-0.00419211]]
# --The solution vector x_7939:
# [[ 0.11508185]
#  [-0.01147321]
#  [ 0.05674512]
#  [ 0.05791167]]
#
# ****************************************************
# --At iteration: 7939
# --The gradient vector g(x_7939):
# [[ 0.00817383]
#  [-0.00081007]
#  [ 0.00394582]
#  [ 0.00419121]]
# --The norm of the gradient vector |g(x_7939)|: 0.010030124516193995
# --The h vector h_7939:
# [[-0.00817383]
#  [ 0.00081007]
#  [-0.00394582]
#  [-0.00419121]]
# --The solution vector x_7940:
# [[ 0.11507368]
#  [-0.0114724 ]
#  [ 0.05674118]
#  [ 0.05790748]]
#
# ****************************************************
# --At iteration: 7940
# --The gradient vector g(x_7940):
# [[ 0.00817212]
#  [-0.0008099 ]
#  [ 0.00394501]
#  [ 0.00419032]]
# --The norm of the gradient vector |g(x_7940)|: 0.010028028674719915
# --The h vector h_7940:
# [[-0.00817212]
#  [ 0.0008099 ]
#  [-0.00394501]
#  [-0.00419032]]
# --The solution vector x_7941:
# [[ 0.11506551]
#  [-0.01147159]
#  [ 0.05673723]
#  [ 0.05790329]]
#
# ****************************************************
# --At iteration: 7941
# --The gradient vector g(x_7941):
# [[ 0.00817041]
#  [-0.00080974]
#  [ 0.0039442 ]
#  [ 0.00418943]]
# --The norm of the gradient vector |g(x_7941)|: 0.010025933554617427
# --The h vector h_7941:
# [[-0.00817041]
#  [ 0.00080974]
#  [-0.0039442 ]
#  [-0.00418943]]
# --The solution vector x_7942:
# [[ 0.11505734]
#  [-0.01147078]
#  [ 0.05673329]
#  [ 0.0578991 ]]
#
# ****************************************************
# --At iteration: 7942
# --The gradient vector g(x_7942):
# [[ 0.0081687 ]
#  [-0.00080957]
#  [ 0.0039434 ]
#  [ 0.00418854]]
# --The norm of the gradient vector |g(x_7942)|: 0.010023839155541893
# --The h vector h_7942:
# [[-0.0081687 ]
#  [ 0.00080957]
#  [-0.0039434 ]
#  [-0.00418854]]
# --The solution vector x_7943:
# [[ 0.11504917]
#  [-0.01146997]
#  [ 0.05672934]
#  [ 0.05789491]]
#
# ****************************************************
# --At iteration: 7943
# --The gradient vector g(x_7943):
# [[ 0.008167  ]
#  [-0.0008094 ]
#  [ 0.00394259]
#  [ 0.00418765]]
# --The norm of the gradient vector |g(x_7943)|: 0.010021745477148854
# --The h vector h_7943:
# [[-0.008167  ]
#  [ 0.0008094 ]
#  [-0.00394259]
#  [-0.00418765]]
# --The solution vector x_7944:
# [[ 0.115041  ]
#  [-0.01146916]
#  [ 0.0567254 ]
#  [ 0.05789072]]
#
# ****************************************************
# --At iteration: 7944
# --The gradient vector g(x_7944):
# [[ 0.00816529]
#  [-0.00080923]
#  [ 0.00394178]
#  [ 0.00418676]]
# --The norm of the gradient vector |g(x_7944)|: 0.01001965251909409
# --The h vector h_7944:
# [[-0.00816529]
#  [ 0.00080923]
#  [-0.00394178]
#  [-0.00418676]]
# --The solution vector x_7945:
# [[ 0.11503284]
#  [-0.01146835]
#  [ 0.05672146]
#  [ 0.05788654]]
#
# ****************************************************
# --At iteration: 7945
# --The gradient vector g(x_7945):
# [[ 0.00816359]
#  [-0.00080906]
#  [ 0.00394098]
#  [ 0.00418587]]
# --The norm of the gradient vector |g(x_7945)|: 0.010017560281033577
# --The h vector h_7945:
# [[-0.00816359]
#  [ 0.00080906]
#  [-0.00394098]
#  [-0.00418587]]
# --The solution vector x_7946:
# [[ 0.11502467]
#  [-0.01146754]
#  [ 0.05671752]
#  [ 0.05788235]]
#
# ****************************************************
# --At iteration: 7946
# --The gradient vector g(x_7946):
# [[ 0.00816188]
#  [-0.00080889]
#  [ 0.00394017]
#  [ 0.00418498]]
# --The norm of the gradient vector |g(x_7946)|: 0.010015468762623506
# --The h vector h_7946:
# [[-0.00816188]
#  [ 0.00080889]
#  [-0.00394017]
#  [-0.00418498]]
# --The solution vector x_7947:
# [[ 0.11501651]
#  [-0.01146673]
#  [ 0.05671358]
#  [ 0.05787817]]
#
# ****************************************************
# --At iteration: 7947
# --The gradient vector g(x_7947):
# [[ 0.00816018]
#  [-0.00080873]
#  [ 0.00393937]
#  [ 0.00418409]]
# --The norm of the gradient vector |g(x_7947)|: 0.010013377963520271
# --The h vector h_7947:
# [[-0.00816018]
#  [ 0.00080873]
#  [-0.00393937]
#  [-0.00418409]]
# --The solution vector x_7948:
# [[ 0.11500835]
#  [-0.01146592]
#  [ 0.05670964]
#  [ 0.05787398]]
#
# ****************************************************
# --At iteration: 7948
# --The gradient vector g(x_7948):
# [[ 0.00815847]
#  [-0.00080856]
#  [ 0.00393856]
#  [ 0.0041832 ]]
# --The norm of the gradient vector |g(x_7948)|: 0.01001128788338048
# --The h vector h_7948:
# [[-0.00815847]
#  [ 0.00080856]
#  [-0.00393856]
#  [-0.0041832 ]]
# --The solution vector x_7949:
# [[ 0.11500019]
#  [-0.01146511]
#  [ 0.0567057 ]
#  [ 0.0578698 ]]
#
# ****************************************************
# --At iteration: 7949
# --The gradient vector g(x_7949):
# [[ 0.00815677]
#  [-0.00080839]
#  [ 0.00393776]
#  [ 0.00418231]]
# --The norm of the gradient vector |g(x_7949)|: 0.010009198521860956
# --The h vector h_7949:
# [[-0.00815677]
#  [ 0.00080839]
#  [-0.00393776]
#  [-0.00418231]]
# --The solution vector x_7950:
# [[ 0.11499204]
#  [-0.01146431]
#  [ 0.05670176]
#  [ 0.05786562]]
#
# ****************************************************
# --At iteration: 7950
# --The gradient vector g(x_7950):
# [[ 0.00815507]
#  [-0.00080822]
#  [ 0.00393695]
#  [ 0.00418142]]
# --The norm of the gradient vector |g(x_7950)|: 0.010007109878618718
# --The h vector h_7950:
# [[-0.00815507]
#  [ 0.00080822]
#  [-0.00393695]
#  [-0.00418142]]
# --The solution vector x_7951:
# [[ 0.11498388]
#  [-0.0114635 ]
#  [ 0.05669783]
#  [ 0.05786143]]
#
# ****************************************************
# --At iteration: 7951
# --The gradient vector g(x_7951):
# [[ 0.00815337]
#  [-0.00080806]
#  [ 0.00393615]
#  [ 0.00418053]]
# --The norm of the gradient vector |g(x_7951)|: 0.010005021953311008
# --The h vector h_7951:
# [[-0.00815337]
#  [ 0.00080806]
#  [-0.00393615]
#  [-0.00418053]]
# --The solution vector x_7952:
# [[ 0.11497573]
#  [-0.01146269]
#  [ 0.05669389]
#  [ 0.05785725]]
#
# ****************************************************
# --At iteration: 7952
# --The gradient vector g(x_7952):
# [[ 0.00815167]
#  [-0.00080789]
#  [ 0.00393535]
#  [ 0.00417964]]
# --The norm of the gradient vector |g(x_7952)|: 0.010002934745595262
# --The h vector h_7952:
# [[-0.00815167]
#  [ 0.00080789]
#  [-0.00393535]
#  [-0.00417964]]
# --The solution vector x_7953:
# [[ 0.11496758]
#  [-0.01146188]
#  [ 0.05668995]
#  [ 0.05785307]]
#
# ****************************************************
# --At iteration: 7953
# --The gradient vector g(x_7953):
# [[ 0.00814997]
#  [-0.00080772]
#  [ 0.00393454]
#  [ 0.00417875]]
# --The norm of the gradient vector |g(x_7953)|: 0.01000084825512914
# --The h vector h_7953:
# [[-0.00814997]
#  [ 0.00080772]
#  [-0.00393454]
#  [-0.00417875]]
# --The solution vector x_7954:
# [[ 0.11495943]
#  [-0.01146107]
#  [ 0.05668602]
#  [ 0.0578489 ]]
#
# ****************************************************
# --At iteration: 7954
# --The gradient vector g(x_7954):
# [[ 0.00814827]
#  [-0.00080755]
#  [ 0.00393374]
#  [ 0.00417787]]
# --The norm of the gradient vector |g(x_7954)|: 0.0099987624815705
